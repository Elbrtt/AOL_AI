# %%
from tensorflow.keras.models import load_model
import numpy as np

# %%
model = load_model("models/modeltest.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
data_baru = np.array([[
    17.99,10.38,122.8,1001,0.1184,0.2776,0.3001,0.1471,0.2419,0.07871,
    1.095,0.9053,8.589,153.4,0.006399,0.04904,0.05373,0.01587,0.03003,0.006193,
    25.38,17.33,184.6,2019,0.1622,0.6656,0.7119,0.2654,0.4601,0.1189
]])

# Prediksi
p = model.predict(data_baru)
print("Probabilitas kanker (malignant):", p[0][0])

# Binerkan
hasil = 1 if p[0][0] >= 0.5 else 0
print("Diagnosis:", hasil)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Probabilitas kanker (malignant): 0.9975121
# Diagnosis: 1
